# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import pandas as pd
# %matplotlib inline
# Importing the dataset
dataset = pd.read_csv(r'C:\Users\Aleks\Desktop\weather.csv')
dataset.head()
# Out:
#               datetime  humidity  pressure  temperature  wind_direction  \
# 0  2015-06-28 23:00:00        60      1007      294.480             260
# 1  2015-06-22 21:00:00        47      1024      301.300             297
# 2  2015-06-23 00:00:00        48      1024      299.894             309
# 3  2015-06-19 20:00:00        88      1023      295.710             332
# 4  2015-06-20 21:00:00        97      1027      292.926             131
#
#    wind_speed  label
# 0           3   rain
# 1           2  clear
# 2           1  clear
# 3           2   rain
# 4           2   rain

# %%
print(dataset.shape)
# Out:
# (60, 7)

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
# datetime          60 non-null object
# humidity          60 non-null int64
# pressure          60 non-null int64
# temperature       60 non-null float64
# wind_direction    60 non-null int64
# wind_speed        60 non-null int64
# label             60 non-null object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 3.4+ KB
# None

# %%
print(dataset.describe())
# Out:
#         humidity     pressure  temperature  wind_direction  wind_speed
# count  60.000000    60.000000    60.000000       60.000000   60.000000
# mean   73.350000  1020.366667   294.511283      221.516667    2.650000
# std    17.803851     7.137788     3.831849       84.280301    1.204863
# min    42.000000  1005.000000   284.320000       30.000000    1.000000
# 25%    59.750000  1016.000000   292.659750      149.250000    2.000000
# 50%    71.000000  1022.000000   294.047000      241.000000    3.000000
# 75%    90.000000  1025.250000   296.827500      292.750000    3.000000
# max    97.000000  1034.000000   302.890000      356.000000    5.000000

# %%
#box and whisker plots
dataset.plot(kind='box', sharex=False, sharey=False)

# %%
dataset.boxplot(by="label",figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CDF3EC32B0>,
# ...
#       dtype=object)

# %%
# histograms
dataset.hist(edgecolor='black', linewidth=1.3,figsize=(20,20))
sns.violinplot(data=dataset,x="label", y="wind_speed")
# Out:
# C:\Users\Aleks\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from pandas.plotting import scatter_matrix
# scatter plot matrix
scatter_matrix(dataset,figsize=(40,40))
plt.show()
# Out:
# C:\Users\Aleks\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(dataset, hue="label")
# Out:
# C:\Users\Aleks\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(dataset, hue="label", diag_kind="kde", markers="+",
...                  plot_kws=dict(s=50, edgecolor="b", linewidth=1),
...                  diag_kws=dict(shade=True))
# Out:
# C:\Users\Aleks\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import pandas as pd
# %matplotlib inline
# Importing the dataset
dataset = pd.read_csv(r'C:\Users\student-iiikt\Desktop\weather.csv')
from pandas.plotting import scatter_matrix
# scatter plot matrix
scatter_matrix(dataset,figsize=(20,20), marker='+', range_padding=0.5)
plt.show()
